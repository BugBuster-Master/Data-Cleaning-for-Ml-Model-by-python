# %%
import pandas as pd
import google.colab.files as files # I provide the file and you just dow- and del- this commet

df = pd.read_csv('Student_data.csv')
print("Sample rows")
print(df.head())

print("Dataset shape")
print(f'Rows {df.shape[0]} Colouns {df.shape[1]}')

print("Dataset info")
print(df.info())

print("Dataset Statistics")
print(df.describe(include='all'))

print('Missing values')
print(df.isnull().sum())

print('Duplicated values')
print(df.duplicated().sum())

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import google.colab.files as files # I provide the file and you just dow- and del- this commet

df = pd.read_csv('Student_data.csv')

print("find the null place")
print(df.isnull().sum())

le = LabelEncoder()
df['Internet'] = le.fit_transform(df['Internet'])
df['Passed'] = le.fit_transform(df['Passed'])

print('After label encoding')
print(df.head())

print("Data type")
print(df.dtypes)
